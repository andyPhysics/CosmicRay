# %%
import numpy as np

# %%
all = np.load('/home/andres/CosmicRay.git/trunk/NN/All_output.npy',allow_pickle=True).item()

# %%
x = np.load('/home/andres/CosmicRay.git/trunk/NN/All_split.npy',allow_pickle=True).item()

# %%
y = x['pred']
print(x['true'])
z1 = zip(*y[0])[1]
z2 = zip(*y[1])[1]
z3 = zip(*y[2])[1]
z4 = zip(*y[3])[1]
# Out:
# [array([[5.56159114, 2.03972077],
#        [5.95978151, 2.03972077],
#        [5.95978151, 2.03972077],
#        ...,
#        [8.72124792, 2.03972077],
#        [9.33302744, 2.03972077],
#        [9.41500272, 2.03972077]]), array([[5.55416491, 1.        ],
#        [5.55416491, 1.        ],
#        [5.60695671, 1.        ],
#        ...,
#        [9.36296211, 1.        ],
#        [9.36296211, 1.        ],
#        [9.36296211, 1.        ]]), array([[5.90814133, 4.01901377],
#        [6.03927325, 4.01901377],
#        [6.3866275 , 4.01901377],
#        ...,
#        [9.12691285, 4.01901377],
#        [9.12691285, 4.01901377],
#        [9.12691285, 4.01901377]]), array([[5.62731179, 3.07944154],
#        [5.62731179, 3.07944154],
#        [5.62731179, 3.07944154],
#        ...,
#        [9.08348661, 3.07944154],
#        [9.27018079, 3.07944154],
#        [9.27018079, 3.07944154]])]

# %%
import matplotlib.pylab as plt
import matplotlib

# %%
print(z3[1])
# Out:
# 3.5551674

# %%
plt.hist(z3,bins=100)
plt.xlabel('Mass')
plt.ylabel('Counts')
plt.savefig('Iron_mass_all.png')

# %%
plt.hist(z4,bins=100)
plt.xlabel('Mass')
plt.ylabel('Counts')
plt.savefig('Oxygen_mass_all.png')

# %%
plt.hist(z1,bins=100)
plt.xlabel('Mass')
plt.ylabel('Counts')
plt.savefig('Helium_mass_all.png')

# %%
plt.hist(z2,bins=100)
plt.xlabel('Mass')
plt.ylabel('Counts')
plt.savefig('Proton_mass_all.png')

# %%
labels = all['true']
predict = all['pred']
print(predict)
# Out:
# [[5.9406614 2.3677652]
#  [6.249752  2.0775611]
#  [6.225316  1.640181 ]
#  ...
#  [8.440763  1.5407239]
#  [8.680767  2.770855 ]
#  [8.6886635 2.6683245]]

# %%
plt.hist(zip(*predict)[1],bins=100)
plt.xlabel('Mass')
plt.ylabel('Counts')
plt.savefig('binned_all_mass.png')
